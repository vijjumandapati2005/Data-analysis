# %%
#matplotlib is only used for decoration and font color addings to the graphs
import numpy as np
import matplotlib.pyplot as plt
runs = np.array([100,50,91,78,89,25,34,19,9,10]) #runs
w = np.array([1,0,2,0,3,7,8,9,7,5]) #wickets
plt.scatter(w,runs,color='black') #x-axis and y-axis
plt.title('IndvsAus_score')
plt.show() #instead of printing we use ploting

# %%
tigar=np.linspace(-2*np.pi,2*np.pi,100)
print(tigar)
# Out:
# [-6.28318531 -6.15625227 -6.02931923 -5.9023862  -5.77545316 -5.64852012
#  -5.52158709 -5.39465405 -5.26772102 -5.14078798 -5.01385494 -4.88692191
#  -4.75998887 -4.63305583 -4.5061228  -4.37918976 -4.25225672 -4.12532369
#  -3.99839065 -3.87145761 -3.74452458 -3.61759154 -3.4906585  -3.36372547
#  -3.23679243 -3.10985939 -2.98292636 -2.85599332 -2.72906028 -2.60212725
#  -2.47519421 -2.34826118 -2.22132814 -2.0943951  -1.96746207 -1.84052903
#  -1.71359599 -1.58666296 -1.45972992 -1.33279688 -1.20586385 -1.07893081
#  -0.95199777 -0.82506474 -0.6981317  -0.57119866 -0.44426563 -0.31733259
#  -0.19039955 -0.06346652  0.06346652  0.19039955  0.31733259  0.44426563
#   0.57119866  0.6981317   0.82506474  0.95199777  1.07893081  1.20586385
#   1.33279688  1.45972992  1.58666296  1.71359599  1.84052903  1.96746207
#   2.0943951   2.22132814  2.34826118  2.47519421  2.60212725  2.72906028
#   2.85599332  2.98292636  3.10985939  3.23679243  3.36372547  3.4906585
# ...

# %%
plt.plot(tigar,np.sin(tigar),color='black',linestyle='dotted') #sin plt.plot(x,y,,color,labels....)
print(tigar)
plt.title("sin(x)") #display plot
plt.show
# Out:
# [-6.28318531 -6.15625227 -6.02931923 -5.9023862  -5.77545316 -5.64852012
#  -5.52158709 -5.39465405 -5.26772102 -5.14078798 -5.01385494 -4.88692191
#  -4.75998887 -4.63305583 -4.5061228  -4.37918976 -4.25225672 -4.12532369
#  -3.99839065 -3.87145761 -3.74452458 -3.61759154 -3.4906585  -3.36372547
#  -3.23679243 -3.10985939 -2.98292636 -2.85599332 -2.72906028 -2.60212725
#  -2.47519421 -2.34826118 -2.22132814 -2.0943951  -1.96746207 -1.84052903
#  -1.71359599 -1.58666296 -1.45972992 -1.33279688 -1.20586385 -1.07893081
#  -0.95199777 -0.82506474 -0.6981317  -0.57119866 -0.44426563 -0.31733259
#  -0.19039955 -0.06346652  0.06346652  0.19039955  0.31733259  0.44426563
#   0.57119866  0.6981317   0.82506474  0.95199777  1.07893081  1.20586385
#   1.33279688  1.45972992  1.58666296  1.71359599  1.84052903  1.96746207
#   2.0943951   2.22132814  2.34826118  2.47519421  2.60212725  2.72906028
#   2.85599332  2.98292636  3.10985939  3.23679243  3.36372547  3.4906585
# ...

# %%
sal = np.array([12000,60000,80000,76000])
wd = np.array([210,300,230,256])
years = [1,2]
bonus=[]
for i,j in zip(sal,wd):
  if j > 250:
    i = i+i*0.1
    bonus.append(i)
  else:
    i = i-i*0.1
    bonus.append(i)
print(bonus)
# Out:
# [10800.0, 66000.0, 72000.0, 83600.0]

# %%
overs = np.arange(5,50,5)
overs_a = np.arange(5,30,5) #creating y
runs_i = np.array([25,51,84,131,160,189,220,250,267])
runs_a = np.array([15,41,94,110,151])
wickets = np.array([12,32,96]) #plotting
plt.plot(overs,runs_i,color='blue',label='India')
plt.scatter(overs_a,runs_a,color='yellow',label = 'Aus') #combining two graphs
plt.legend(loc='best') #displaying the final graph
plt.show()

# %%
import matplotlib.pyplot as plt
a = [230,560,780,127,128]
b = [200,160,270,127,400]
years = [1,2,3,4]
profit_a = [(a[i]-a[i-1]) for i in range(1,len(a))]
profit_b = [(b[i]-b[i-1]) for i in range(1,len(b))]
plt.subplot(2,1,2)
plt.plot(years,profit_a,color='hotpink',linewidth = '7',label =
'CompanyA',marker='.',ms='15',mec='r')
plt.subplot(2,1,1)
plt.plot(years,profit_b,color='black',linestyle='dotted',label =
'CompanyB',marker = 'H')
plt.show()

# %%
#inverse trig
print(np.arcsin(1)) #sin^-1
print(np.arccos(1))
print(np.arctan(0))
# Out:
# 1.5707963267948966
# 0.0
# 0.0

# %%
a = np.array([23,56,78,12,45,89,10,89,34,89,23,77]) #mean
print(np.mean(a)) #median
print(np.median(a)) #mode print(np.mode(a))
52.083333333333336
50.5
a = np.array([23,56,78,12,45,89,10,89,34,89,23,77])
b = np.array([23,56,78,12,40,90,10,85,31,89,23,77]) #var
print(np.var(a)) #std
print(np.std(a)) #corrcoef
print(np.corrcoef(a,b))
903.5763888888888
30.059547383300515
[[1. 0.9981131]
 [0.9981131 1. ]]  #vector length : |V| = √(x2 + y2 + z2)
a = np.array([2,5,7])
print(sqrt((sum(a**2))))
8.831760866327848
a = np.array([25,60,5,10])
labe = ["AIML","Python","Pandas","Numpy"]
plt.pie(a,labels = labe)
plt.show()
# Out:
#   File "<ipython-input-54-f4430cc93d7b>", line 13
#     [[1. 0.9981131]
#       ^
# SyntaxError: invalid syntax. Perhaps you forgot a comma?

# %%
a = np.array([25,60,5,10])
labe = ["AIML","Python","Pandas","Numpy"]
explo = [0.2,0.15,0,0]
plt.pie(a,labels = labe,explode = explo,startangle = 180)
plt.show()

# %%
a = np.array([25,60,5,10])
labe = ["AIML","Python","Pandas","Numpy"]
explo = [0.3,0,0,0]
plt.pie(a,labels = labe,explode = explo,shadow=True)
plt.legend()
plt.show()

# %%
a = np.array([25,60,5,10])
labe = ["AIML","Python","Pandas","Numpy"]
color = ['green','red','coral','yellow']
plt.pie(a,labels = labe,colors= color)


plt.show()

# %%
a = np.array([2+1j])
print(a.real)
# Out:
# [2.]

# %%
a=np.array([180,90,180])
print(np.deg2rad(a))
# Out:
# [3.14159265 1.57079633 3.14159265]

# %%
pip install seaborn

# %%
#load example dataset
import seaborn as sns #create a scatter plot
import matplotlib.pyplot as plt
print(iris)
iris=sns.load_dataset("iris")
print(iris)
sns.scatterplot(x="petal_length",y="sepal_width",data=iris,label='graph')
plt.title("scatter plot sepal_length vs.iris")
plt.xlabel("petal_length ($)")
plt.ylabel("sepal_width ($)")
plt.show()
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]
#      sepal_length  sepal_width  petal_length  petal_width    species
# ...

# %%
import seaborn as sns
import matplotlib.pyplot as plt
tips=sns.load_dataset("tips")
print(tips)
sns.barplot(x="day",y="tip ",data=tips)
plt.title("scatter plot sepal_length va.tips")
plt.xlabel("day ($)")
plt.ylabel("tip ($)")
plt.show()
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-105-319ff48c3349> in <cell line: 5>()
#       3 tips=sns.load_dataset("tips")
# ...

# %%
import seaborn as sns #create a scatter plot
import matplotlib.pyplot as plt
iris=sns.load_dataset("iris")
print(iris)
sns.boxplot(x="petal_length",y="sepal_width ",data=iris)
plt.title("scatter plot sepal_length vs.iris")
plt.xlabel("petal_length ($)")
plt.ylabel("sepal_width ($)")
plt.show()
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]
# ---------------------------------------------------------------------------
# ...

# %%
import seaborn as sns #create a scatter plot
import matplotlib.pyplot as plt
iris=sns.load_dataset("iris")
print(iris)
sns.violinplot(x="petal_length",y="sepal_width ",data=iris)
plt.title("scatter plot sepal_length vs.iris")
plt.xlabel("petal_length ($)")
plt.ylabel("sepal_width ($)")
plt.show()
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]
# ---------------------------------------------------------------------------
# ...

# %%
import seaborn as sns
import matplotlib.pyplot as plt
#load example dataset
tips=sns.load_dataset("tips")
print(tips)
sns.barplot(x="day",y="total_bill",data=tips)
plt.title("average total bill by day")
plt.xlabel("Day of the week")
plt.ylabel("Average total bill($)")
plt.show()
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
tips=sns.load_dataset("tips")
sns.violinplot(x="day",y="total_bill",data=tips)
plt.title("Distribution of totalbill by day")
plt.xlabel("Day of the week")
plt.ylabel("Total Bill($)")
plt.show()

# %%
import pandas as pd
import seaborn as sns
a=pd.read_csv("/content/drive/MyDrive/Dataset/Copy of diabetcsv.csv")
b=sns.lineplot(x="pres",y="plas",data=a)
plt.show()

# %%
iris=sns.load_dataset("iris")
correlation_matrix=iris.corr()
sns.heatmap(correlation_matrix,annot=True, cmap="coolwarm")
plt.title("correlation Heatmap of Iris Dataset")
plt.show()
# Out:
# <ipython-input-112-92f3480365b5>:2: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   correlation_matrix=iris.corr()

# %%
import seaborn as sns
import matplotlib.pyplot as plt
#load example dataset
tips=sns.load_dataset("tips")
print(tips)
sns.jointplot(x="day",y="total_bill",data=tips)
plt.title("average total bill by day")
plt.xlabel("Day of the week")
plt.ylabel("Average total bill($)")
plt.show()
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
import seaborn as sns
import matplotlib.pyplot as plt
#load example dataset
titanic=sns.load_dataset("titanic")
print(titanic)
sns.countplot(x="class",data=titanic)
plt.title("class distribution")
plt.xlabel("Class")
plt.ylabel("Count")
plt.show()
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %%
import seaborn as sns
import matplotlib.pyplot as plt
#load example dataset
tips=sns.load_dataset("tips")
print(tips)
sns.lmplot(x="tip",y="total_bill",data=tips)
plt.title("average total bill by day")
plt.xlabel("tip ($)")
plt.ylabel("Average total bill($)")
plt.show()
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
import seaborn as sns
import matplotlib.pyplot as plt
#load example dataset
titanic=sns.load_dataset("titanic")
print(titanic)
g=sns.FacetGrid(titanic,col="class")
g.map(sns.histplot,"age")
plt.subplots_adjust(top=0.8)
g.fig.suptitle("age distribution by passenger class")
plt.show()
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %%
import seaborn as sns
import matplotlib.pyplot as plt
diamonds=sns.load_dataset("diamonds")
print(diamonds)
correlation_matrix=diamonds.corr()
sns.heatmap(correlation_matrix,annot=True, cmap="coolwarm")
plt.title("correlation Heatmap of diamonds Dataset")
plt.show()
# Out:
#        carat        cut color clarity  depth  table  price     x     y     z
# 0       0.23      Ideal     E     SI2   61.5   55.0    326  3.95  3.98  2.43
# 1       0.21    Premium     E     SI1   59.8   61.0    326  3.89  3.84  2.31
# 2       0.23       Good     E     VS1   56.9   65.0    327  4.05  4.07  2.31
# 3       0.29    Premium     I     VS2   62.4   58.0    334  4.20  4.23  2.63
# 4       0.31       Good     J     SI2   63.3   58.0    335  4.34  4.35  2.75
# ...      ...        ...   ...     ...    ...    ...    ...   ...   ...   ...
# 53935   0.72      Ideal     D     SI1   60.8   57.0   2757  5.75  5.76  3.50
# 53936   0.72       Good     D     SI1   63.1   55.0   2757  5.69  5.75  3.61
# 53937   0.70  Very Good     D     SI1   62.8   60.0   2757  5.66  5.68  3.56
# 53938   0.86    Premium     H     SI2   61.0   58.0   2757  6.15  6.12  3.74
# 53939   0.75      Ideal     D     SI2   62.2   55.0   2757  5.83  5.87  3.64
#
# [53940 rows x 10 columns]
# ...

# %%
import seaborn as sns
import matplotlib.pyplot as plt
fights=sns.load_dataset("planets")
print(planets)
correlation_matrix=planets.corr()
sns.heatmap(correlation_matrix,annot=True, cmap="coolwarm")
plt.title("correlation Heatmap of planets Dataset")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-14-0238dab49217> in <cell line: 4>()
#       2 import matplotlib.pyplot as plt
#       3 fights=sns.load_dataset("planets")
# ----> 4 print(planets)
#       5 correlation_matrix=planets.corr()
#       6 sns.heatmap(correlation_matrix,annot=True, cmap="coolwarm")
#
# NameError: name 'planets' is not defined

# %%
import seaborn as sns
import matplotlib.pyplot as plt
fights=sns.load_dataset("mpg")
print(mpg)
correlation_matrix=planets.corr()
sns.heatmap(correlation_matrix,annot=True, cmap="coolwarm")
plt.title("correlation Heatmap of planets Dataset")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-15-83ff28c9bc81> in <cell line: 4>()
#       2 import matplotlib.pyplot as plt
#       3 fights=sns.load_dataset("mpg")
# ----> 4 print(mpg)
#       5 correlation_matrix=planets.corr()
#       6 sns.heatmap(correlation_matrix,annot=True, cmap="coolwarm")
#
# NameError: name 'mpg' is not defined
