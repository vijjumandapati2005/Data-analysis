# %%
import pandas as pd
a = ['rama','Ramya','Durga','nagendra ','Lahari','Sunny','rohith']
r=pd.Series(a, index = [67,43,44,89,34,45,23])
print(r)
# Out:
# 67         rama
# 43        Ramya
# 44        Durga
# 89    nagendra
# 34       Lahari
# 45        Sunny
# 23       rohith
# dtype: object

# %%
df=pd.read_csv("/content/diabetcsv.csv")
print(df)
# Out:
#      preg  plas  pres  skin  insu  mass   pedi  age            class
# 0       6   148    72    35     0  33.6  0.627   50  tested_positive
# 1       1    85    66    29     0  26.6  0.351   31  tested_negative
# 2       8   183    64     0     0  23.3  0.672   32  tested_positive
# 3       1    89    66    23    94  28.1  0.167   21  tested_negative
# 4       0   137    40    35   168  43.1  2.288   33  tested_positive
# ..    ...   ...   ...   ...   ...   ...    ...  ...              ...
# 763    10   101    76    48   180  32.9  0.171   63  tested_negative
# 764     2   122    70    27     0  36.8  0.340   27  tested_negative
# 765     5   121    72    23   112  26.2  0.245   30  tested_negative
# 766     1   126    60     0     0  30.1  0.349   47  tested_positive
# 767     1    93    70    31     0  30.4  0.315   23  tested_negative
#
# [768 rows x 9 columns]

# %%
df=pd.read_excel("/content/drive/MyDrive/Dataset/Copy of grades_withnulls (1).xlsx")
print(df)
# Out:
#      Names Initials  SEM1  SEM2  SEM3 Grade  Placed
# 0      Joe        K   9.8  10.0   9.9    A+       1
# 1   Rajesh        M   8.9   9.1   9.3     A       1
# 2   Kissan        V   9.9   9.8  10.0     A       0
# 3     Mary        N   7.7   8.0   NaN     B       0
# 4     Jeen        K   9.8   9.1   9.9    A+       1
# 5      Raj        M   8.9   9.1   9.3     A       1
# 6   Hassan        V   9.9   9.0   9.2     A       1
# 7     Mari        N   7.7   8.0   7.1     B       1
# 8     Jess        K   NaN   9.1   9.9    A+       1
# 9   Rajini        M   NaN   9.1   9.3     A       0
# 10   Kiran        V   NaN   9.3   9.2     A       0
# 11    Maya        N   7.7   8.0   7.1     B       0
# 12   Jolin        K   9.8   9.1   9.9    A+       1
# 13  Rajesh        M   8.9   9.1   9.3     A       1
# 14    Riya        M   9.3   9.9  10.0     A       1
# 15    Sana        V   9.9   9.3   9.2     A       0
# 16    Mark        N   7.7   8.0   7.0     B       0

# %%
df=pd.read_excel("/content/drive/MyDrive/Dataset/Copy of grades_withnulls (1).xlsx",sheet_name=0)
print(df)
# Out:
#      Names Initials  SEM1  SEM2  SEM3 Grade  Placed
# 0      Joe        K   9.8  10.0   9.9    A+       1
# 1   Rajesh        M   8.9   9.1   9.3     A       1
# 2   Kissan        V   9.9   9.8  10.0     A       0
# 3     Mary        N   7.7   8.0   NaN     B       0
# 4     Jeen        K   9.8   9.1   9.9    A+       1
# 5      Raj        M   8.9   9.1   9.3     A       1
# 6   Hassan        V   9.9   9.0   9.2     A       1
# 7     Mari        N   7.7   8.0   7.1     B       1
# 8     Jess        K   NaN   9.1   9.9    A+       1
# 9   Rajini        M   NaN   9.1   9.3     A       0
# 10   Kiran        V   NaN   9.3   9.2     A       0
# 11    Maya        N   7.7   8.0   7.1     B       0
# 12   Jolin        K   9.8   9.1   9.9    A+       1
# 13  Rajesh        M   8.9   9.1   9.3     A       1
# 14    Riya        M   9.3   9.9  10.0     A       1
# 15    Sana        V   9.9   9.3   9.2     A       0
# 16    Mark        N   7.7   8.0   7.0     B       0

# %%
df=pd.read_excel("/content/drive/MyDrive/Dataset/Copy of grades_withnulls (1).xlsx")
print(df.head()) #for how many rows and how many columns
print(df.tail(n=10))
# Out:
#     Names Initials  SEM1  SEM2  SEM3 Grade  Placed
# 0     Joe        K   9.8  10.0   9.9    A+       1
# 1  Rajesh        M   8.9   9.1   9.3     A       1
# 2  Kissan        V   9.9   9.8  10.0     A       0
# 3    Mary        N   7.7   8.0   NaN     B       0
# 4    Jeen        K   9.8   9.1   9.9    A+       1
#      Names Initials  SEM1  SEM2  SEM3 Grade  Placed
# 7     Mari        N   7.7   8.0   7.1     B       1
# 8     Jess        K   NaN   9.1   9.9    A+       1
# 9   Rajini        M   NaN   9.1   9.3     A       0
# 10   Kiran        V   NaN   9.3   9.2     A       0
# 11    Maya        N   7.7   8.0   7.1     B       0
# 12   Jolin        K   9.8   9.1   9.9    A+       1
# 13  Rajesh        M   8.9   9.1   9.3     A       1
# 14    Riya        M   9.3   9.9  10.0     A       1
# 15    Sana        V   9.9   9.3   9.2     A       0
# 16    Mark        N   7.7   8.0   7.0     B       0

# %%
df=pd.read_csv("/content/drive/MyDrive/Dataset/Copy of diabetcsv.csv")
print(df.describe) #first 5 last 5
# Out:
# <bound method NDFrame.describe of      preg  plas  pres  skin  insu  mass   pedi  age            class
# 0       6   148    72    35     0  33.6  0.627   50  tested_positive
# 1       1    85    66    29     0  26.6  0.351   31  tested_negative
# 2       8   183    64     0     0  23.3  0.672   32  tested_positive
# 3       1    89    66    23    94  28.1  0.167   21  tested_negative
# 4       0   137    40    35   168  43.1  2.288   33  tested_positive
# ..    ...   ...   ...   ...   ...   ...    ...  ...              ...
# 763    10   101    76    48   180  32.9  0.171   63  tested_negative
# 764     2   122    70    27     0  36.8  0.340   27  tested_negative
# 765     5   121    72    23   112  26.2  0.245   30  tested_negative
# 766     1   126    60     0     0  30.1  0.349   47  tested_positive
# 767     1    93    70    31     0  30.4  0.315   23  tested_negative
#
# [768 rows x 9 columns]>

# %%
df=pd.read_csv("/content/drive/MyDrive/Dataset/Copy of diabetcsv.csv")
print(df.describe().T) # transpose row will be column ,column will be row
# Out:
#       count        mean         std     min       25%       50%        75%  \
# preg  768.0    3.845052    3.369578   0.000   1.00000    3.0000    6.00000
# plas  768.0  120.894531   31.972618   0.000  99.00000  117.0000  140.25000
# pres  768.0   69.105469   19.355807   0.000  62.00000   72.0000   80.00000
# skin  768.0   20.536458   15.952218   0.000   0.00000   23.0000   32.00000
# insu  768.0   79.799479  115.244002   0.000   0.00000   30.5000  127.25000
# mass  768.0   31.992578    7.884160   0.000  27.30000   32.0000   36.60000
# pedi  768.0    0.471876    0.331329   0.078   0.24375    0.3725    0.62625
# age   768.0   33.240885   11.760232  21.000  24.00000   29.0000   41.00000
#
#          max
# preg   17.00
# plas  199.00
# pres  122.00
# skin   99.00
# insu  846.00
# mass   67.10
# pedi    2.42
# age    81.00

# %%
df=pd.read_csv("/content/drive/MyDrive/Dataset/Copy of diabetcsv.csv")
print(df.shape) #get the no.of rows and columns
print(df.shape[0]) #get the no.of rows only
print(df.shape[1]) #get the no.of columns only
# Out:
# (768, 9)
# 768
# 9

# %%
df=pd.read_csv("/content/drive/MyDrive/Dataset/Copy of diabetcsv.csv")
print(df.columns)
l1=list(df.columns)
print(l1)
# Out:
# Index(['preg', 'plas', 'pres', 'skin', 'insu', 'mass', 'pedi', 'age', 'class'], dtype='object')
# ['preg', 'plas', 'pres', 'skin', 'insu', 'mass', 'pedi', 'age', 'class']

# %%
df=pd.read_csv("/content/drive/MyDrive/Dataset/Copy of diabetcsv.csv")
df2=df.copy()
df2.loc[2:5,'SEM1']=None
df2.head(7)
# Out:
#    preg  plas  pres  skin  insu  mass   pedi  age            class  SEM1
# 0     6   148    72    35     0  33.6  0.627   50  tested_positive   NaN
# 1     1    85    66    29     0  26.6  0.351   31  tested_negative   NaN
# 2     8   183    64     0     0  23.3  0.672   32  tested_positive   NaN
# 3     1    89    66    23    94  28.1  0.167   21  tested_negative   NaN
# 4     0   137    40    35   168  43.1  2.288   33  tested_positive   NaN
# 5     5   116    74     0     0  25.6  0.201   30  tested_negative   NaN
# 6     3    78    50    32    88  31.0  0.248   26  tested_positive   NaN

# %%
df=pd.read_excel("/content/drive/MyDrive/Dataset/Copy of grades_withnulls (1).xlsx")
df2=df.copy()
df2.loc[2:5,'SEM1']=4
df2.head(7)
# Out:
#     Names Initials  SEM1  SEM2  SEM3 Grade  Placed
# 0     Joe        K   9.8  10.0   9.9    A+       1
# 1  Rajesh        M   8.9   9.1   9.3     A       1
# 2  Kissan        V   4.0   9.8  10.0     A       0
# 3    Mary        N   4.0   8.0   NaN     B       0
# 4    Jeen        K   4.0   9.1   9.9    A+       1
# 5     Raj        M   4.0   9.1   9.3     A       1
# 6  Hassan        V   9.9   9.0   9.2     A       1

# %%
df2.isnull().head(7)
# Out:
#     Names  Initials   SEM1   SEM2   SEM3  Grade  Placed
# 13  False     False  False  False  False  False   False
# 14  False     False  False  False  False  False   False
# 15  False     False  False  False  False  False   False
# 16  False     False  False  False  False  False   False

# %%
df2.isnull().tail(7)
# Out:
#     Names  Initials   SEM1   SEM2   SEM3  Grade  Placed
# 10  False     False   True  False  False  False   False
# 11  False     False  False  False  False  False   False
# 12  False     False  False  False  False  False   False
# 13  False     False  False  False  False  False   False
# 14  False     False  False  False  False  False   False
# 15  False     False  False  False  False  False   False
# 16  False     False  False  False  False  False   False

# %%
df.isnull().head(7)
# Out:
#    Names  Initials   SEM1   SEM2   SEM3  Grade  Placed
# 0  False     False  False  False  False  False   False
# 1  False     False  False  False  False  False   False
# 2  False     False  False  False  False  False   False
# 3  False     False  False  False   True  False   False
# 4  False     False  False  False  False  False   False
# 5  False     False  False  False  False  False   False
# 6  False     False  False  False  False  False   False

# %%
df.isnull().tail(4)
# Out:
#     Names  Initials   SEM1   SEM2   SEM3  Grade  Placed
# 13  False     False  False  False  False  False   False
# 14  False     False  False  False  False  False   False
# 15  False     False  False  False  False  False   False
# 16  False     False  False  False  False  False   False

# %%
print(df2.isnull().sum())
# Out:
# Names       0
# Initials    0
# SEM1        3
# SEM2        0
# SEM3        1
# Grade       0
# Placed      0
# dtype: int64

# %%
print(df.isnull().sum())
# Out:
# Names       0
# Initials    0
# SEM1        3
# SEM2        0
# SEM3        1
# Grade       0
# Placed      0
# dtype: int64

# %%
#extracting column
print(df['SEM1'])
# Out:
# 0     9.8
# 1     8.9
# 2     9.9
# 3     7.7
# 4     9.8
# 5     8.9
# 6     9.9
# 7     7.7
# 8     NaN
# 9     NaN
# 10    NaN
# 11    7.7
# 12    9.8
# 13    8.9
# 14    9.3
# 15    9.9
# 16    7.7
# Name: SEM1, dtype: float64

# %%
print(df2['SEM1'])
# Out:
# 0     9.8
# 1     8.9
# 2     4.0
# 3     4.0
# 4     4.0
# 5     4.0
# 6     9.9
# 7     7.7
# 8     NaN
# 9     NaN
# 10    NaN
# 11    7.7
# 12    9.8
# 13    8.9
# 14    9.3
# 15    9.9
# 16    7.7
# Name: SEM1, dtype: float64

# %%
print(df[['SEM1','Names']])
# Out:
#     SEM1   Names
# 0    9.8     Joe
# 1    8.9  Rajesh
# 2    9.9  Kissan
# 3    7.7    Mary
# 4    9.8    Jeen
# 5    8.9     Raj
# 6    9.9  Hassan
# 7    7.7    Mari
# 8    NaN    Jess
# 9    NaN  Rajini
# 10   NaN   Kiran
# 11   7.7    Maya
# 12   9.8   Jolin
# 13   8.9  Rajesh
# 14   9.3    Riya
# 15   9.9    Sana
# 16   7.7    Mark

# %%
print(df[df.index==10]) #printing one row
# Out:
#     Names Initials  SEM1  SEM2  SEM3 Grade  Placed
# 10  Kiran        V   NaN   9.3   9.2     A       0

# %%
print(df[df.index.isin(range(12,15))]) #printing multiple rows
# Out:
#      Names Initials  SEM1  SEM2  SEM3 Grade  Placed
# 12   Jolin        K   9.8   9.1   9.9    A+       1
# 13  Rajesh        M   8.9   9.1   9.3     A       1
# 14    Riya        M   9.3   9.9  10.0     A       1

# %%
print(df2.loc[5]) #printing one row as series
# Out:
# Names       Raj
# Initials      M
# SEM1        4.0
# SEM2        9.1
# SEM3        9.3
# Grade         A
# Placed        1
# Name: 5, dtype: object

# %%
print(df2.loc[7:15,'SEM1']==None)
# Out:
# 7     False
# 8     False
# 9     False
# 10    False
# 11    False
# 12    False
# 13    False
# 14    False
# 15    False
# Name: SEM1, dtype: bool

# %%
df2.loc[10:15,['Names','Grade']]
# Out:
#      Names Grade
# 10   Kiran     A
# 11    Maya     B
# 12   Jolin    A+
# 13  Rajesh     A
# 14    Riya     A
# 15    Sana     A

# %%
df2.iloc[10:14,:3] #[row,column]
# Out:
#      Names Initials  SEM1
# 10   Kiran        V   NaN
# 11    Maya        N   NaN
# 12   Jolin        K   NaN
# 13  Rajesh        M   NaN

# %%
df2.loc[:7,["Names"]] #[row,column]
# Out:
#     Names
# 0     Joe
# 1  Rajesh
# 2  Kissan
# 3    Mary
# 4    Jeen
# 5     Raj
# 6  Hassan
# 7    Mari

# %%
df[df.Grade == 'A']
df[df.SEM2 == 10]
# Out:
#   Names Initials  SEM1  SEM2  SEM3 Grade  Placed
# 0   Joe        K   9.8  10.0   9.9    A+       1

# %%
df2.loc[df['Names']=='Rajesh']
# Out:
#      Names Initials  SEM1  SEM2  SEM3 Grade  Placed
# 1   Rajesh        M   8.9   9.1   9.3     A       1
# 13  Rajesh        M   NaN   9.1   9.3     A       1

# %%
df.loc[df['SEM1']>9.8, ['Names']] #printing names of sem scored more than 9.8
# Out:
#      Names
# 2   Kissan
# 6   Hassan
# 15    Sana

# %%
df3=df2.copy() #df3=df3.dropna(0)
df3
# Out:
#      Names Initials  SEM1  SEM2  SEM3 Grade  Placed
# 0      Joe        K   9.8  10.0   9.9    A+       1
# 1   Rajesh        M   8.9   9.1   9.3     A       1
# 2   Kissan        V   4.0   9.8  10.0     A       0
# 3     Mary        N   4.0   8.0   NaN     B       0
# 4     Jeen        K   4.0   9.1   9.9    A+       1
# 5      Raj        M   4.0   9.1   9.3     A       1
# 6   Hassan        V   9.9   9.0   9.2     A       1
# 7     Mari        N   NaN   8.0   7.1     B       1
# 8     Jess        K   NaN   9.1   9.9    A+       1
# 9   Rajini        M   NaN   9.1   9.3     A       0
# 10   Kiran        V   NaN   9.3   9.2     A       0
# 11    Maya        N   NaN   8.0   7.1     B       0
# 12   Jolin        K   NaN   9.1   9.9    A+       1
# 13  Rajesh        M   NaN   9.1   9.3     A       1
# 14    Riya        M   NaN   9.9  10.0     A       1
# 15    Sana        V   NaN   9.3   9.2     A       0
# 16    Mark        N   7.7   8.0   7.0     B       0

# %%
df3.dropna(inplace=True,axis=1)
df3
# Out:
#      Names Initials  SEM2 Grade  Placed
# 0      Joe        K  10.0    A+       1
# 1   Rajesh        M   9.1     A       1
# 2   Kissan        V   9.8     A       0
# 3     Mary        N   8.0     B       0
# 4     Jeen        K   9.1    A+       1
# 5      Raj        M   9.1     A       1
# 6   Hassan        V   9.0     A       1
# 7     Mari        N   8.0     B       1
# 8     Jess        K   9.1    A+       1
# 9   Rajini        M   9.1     A       0
# 10   Kiran        V   9.3     A       0
# 11    Maya        N   8.0     B       0
# 12   Jolin        K   9.1    A+       1
# 13  Rajesh        M   9.1     A       1
# 14    Riya        M   9.9     A       1
# 15    Sana        V   9.3     A       0
# 16    Mark        N   8.0     B       0

# %%
df3.dropna(inplace=True, how='all')
df3
# Out:
#      Names Initials  SEM2 Grade  Placed
# 0      Joe        K  10.0    A+       1
# 1   Rajesh        M   9.1     A       1
# 2   Kissan        V   9.8     A       0
# 3     Mary        N   8.0     B       0
# 4     Jeen        K   9.1    A+       1
# 5      Raj        M   9.1     A       1
# 6   Hassan        V   9.0     A       1
# 7     Mari        N   8.0     B       1
# 8     Jess        K   9.1    A+       1
# 9   Rajini        M   9.1     A       0
# 10   Kiran        V   9.3     A       0
# 11    Maya        N   8.0     B       0
# 12   Jolin        K   9.1    A+       1
# 13  Rajesh        M   9.1     A       1
# 14    Riya        M   9.9     A       1
# 15    Sana        V   9.3     A       0
# 16    Mark        N   8.0     B       0

# %%
mv=df3['SEM2'].mean()
df3=df3.fillna(mv)
print(df3)
# Out:
#      Names Initials  SEM2 Grade  Placed
# 0      Joe        K  10.0    A+       1
# 1   Rajesh        M   9.1     A       1
# 2   Kissan        V   9.8     A       0
# 3     Mary        N   8.0     B       0
# 4     Jeen        K   9.1    A+       1
# 5      Raj        M   9.1     A       1
# 6   Hassan        V   9.0     A       1
# 7     Mari        N   8.0     B       1
# 8     Jess        K   9.1    A+       1
# 9   Rajini        M   9.1     A       0
# 10   Kiran        V   9.3     A       0
# 11    Maya        N   8.0     B       0
# 12   Jolin        K   9.1    A+       1
# 13  Rajesh        M   9.1     A       1
# 14    Riya        M   9.9     A       1
# 15    Sana        V   9.3     A       0
# 16    Mark        N   8.0     B       0

# %%
print(df3[df3.index==15])
# Out:
#    Names Initials  SEM2 Grade  Placed
# 15  Sana        V   9.3     A       0

# %%
df.isnull()

# %%
df3=df2.copy()
df3
# Out:
#      Names Initials  SEM1  SEM2  SEM3 Grade  Placed
# 0      Joe        K   9.8  10.0   9.9    A+       1
# 1   Rajesh        M   8.9   9.1   9.3     A       1
# 2   Kissan        V   4.0   9.8  10.0     A       0
# 3     Mary        N   4.0   8.0   NaN     B       0
# 4     Jeen        K   4.0   9.1   9.9    A+       1
# 5      Raj        M   4.0   9.1   9.3     A       1
# 6   Hassan        V   9.9   9.0   9.2     A       1
# 7     Mari        N   NaN   8.0   7.1     B       1
# 8     Jess        K   NaN   9.1   9.9    A+       1
# 9   Rajini        M   NaN   9.1   9.3     A       0
# 10   Kiran        V   NaN   9.3   9.2     A       0
# 11    Maya        N   NaN   8.0   7.1     B       0
# 12   Jolin        K   NaN   9.1   9.9    A+       1
# 13  Rajesh        M   NaN   9.1   9.3     A       1
# 14    Riya        M   NaN   9.9  10.0     A       1
# 15    Sana        V   NaN   9.3   9.2     A       0
# 16    Mark        N   7.7   8.0   7.0     B       0

# %%
print(df3[df3.index==11])
# Out:
#    Names Initials  SEM1  SEM2  SEM3 Grade  Placed
# 11  Maya        N   NaN   8.0   7.1     B       0

# %%
df3.loc['SEM2']
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-92-9a6b289ac1b0> in <cell line: 1>()
# ----> 1 df3.loc[SEM2]
#
# NameError: name 'SEM2' is not defined

# %%
a = pd.Series(['venkat','mohith','sairam'])
pd.Series([1,2,3])
print(a)
# Out:
# 0    venkat
# 1    mohith
# 2    sairam
# dtype: object

# %%
df3.dropna()
df3
# Out:
#      Names Initials  SEM1  SEM2  SEM3 Grade  Placed
# 0      Joe        K   9.8  10.0   9.9    A+       1
# 1   Rajesh        M   8.9   9.1   9.3     A       1
# 2   Kissan        V   4.0   9.8  10.0     A       0
# 3     Mary        N   4.0   8.0   NaN     B       0
# 4     Jeen        K   4.0   9.1   9.9    A+       1
# 5      Raj        M   4.0   9.1   9.3     A       1
# 6   Hassan        V   9.9   9.0   9.2     A       1
# 7     Mari        N   NaN   8.0   7.1     B       1
# 8     Jess        K   NaN   9.1   9.9    A+       1
# 9   Rajini        M   NaN   9.1   9.3     A       0
# 10   Kiran        V   NaN   9.3   9.2     A       0
# 11    Maya        N   NaN   8.0   7.1     B       0
# 12   Jolin        K   NaN   9.1   9.9    A+       1
# 13  Rajesh        M   NaN   9.1   9.3     A       1
# 14    Riya        M   NaN   9.9  10.0     A       1
# 15    Sana        V   NaN   9.3   9.2     A       0
# 16    Mark        N   7.7   8.0   7.0     B       0

# %%
df['Grade']
# Out:
# 0     A+
# 1      A
# 2      A
# 3      B
# 4     A+
# 5      A
# 6      A
# 7      B
# 8     A+
# 9      A
# 10     A
# 11     B
# 12    A+
# 13     A
# 14     A
# 15     A
# 16     B
# Name: Grade, dtype: object

# %%
import numpy as np
a=np.array(][1,2],[5,6,7]])
b=np.array([[8,5],[2,7,9]])

# %%
df2 = df2.drop_duplicates()
print(dfn)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-4-1eb9ab07e299> in <cell line: 1>()
# ----> 1 df2 = df2.drop_duplicates()
#       2 print(dfn)
#
# NameError: name 'df2' is not defined
